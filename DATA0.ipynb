# %%
import numpy as np

# %%
new1=np.array([[4,6,'a'],[6,9,'b'],[5,6,0]])
print(new1)

# %%
for row in new1:
    for i in row:
     if  str(i).isnumeric() :
        pass
     else:
      np.delete(new1,np.where(row),axis=0)
print(new1)

# %%
for element in np.nditer(new1):
    print(element, end=' ')

# %%
print(new1.diagonal())

# %%
li=[5,6,7,8]

# %%
print(li[::-1])

# %% [raw]
# new1[(0,2)]=7
# new1[(1,2)]=10

# %%
print(new1)

# %%
new1=np.array([[4,6,'a'],[6,9,'b'],[5,6,0]])
print(new1)

# %%
new1=np.array([[4,6,5],[6,-9,np.nan],[5,6,0]])
ne=np.where(new1==0)
print(ne)

# %%
new1[np.isnan(new1)]=np.nanmean(new1)
print(new1)

# %%
new1[0][0]=10
print(new1)

# %%
import numpy as np
arr=np.array([[1,np.nan,3],
            [5,8,9],
          [np.nan,11,np.nan]])

print(arr[:~np.isnan(arr).any(axis=0)])

# %%
arr=np.array([[ 4. ,    6. ,    5.   ],
 [ 6.  ,  -9.  ,   5.375],
 [ 5.  ,   6.  ,  20.   ]])
print(arr)

# %% [markdown]
# #####

# %%
print(np.any(arr>10,axis=1))

# %%
clear()

# %%
import pandas as pd

# %%
df=pd.DataFrame({'student_id':[101 ,102 ,103 ,104],
                       
                'student_name':['Alice', 'Bob','Charlie', 'David'],                 
                'graduation_year':[2025, 2024, 2025, 2023],
                'total_credits':[130 ,110 ,120 ,140],                       
                'completed_courses': [32, 28, 30, 40]})
print(df)
# Out:
#    student_id student_name  graduation_year  total_credits  completed_courses
# 0         101        Alice             2025            130                 32
# 1         102          Bob             2024            110                 28
# 2         103      Charlie             2025            120                 30
# 3         104        David             2023            140                 40

# %%
  print(df.loc[(df['total_credits']>119) & (df['completed_courses']>29)])
# Out:
#    student_id student_name  graduation_year  total_credits  completed_courses
# 0         101        Alice             2025            130                 32
# 2         103      Charlie             2025            120                 30
# 3         104        David             2023            140                 40
