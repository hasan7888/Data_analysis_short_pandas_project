# %%
import pandas as pd

# %%
df=pd.DataFrame({'product_id': [101,102, 103, 104, 105, 106, 107, 108, 109, 110], 
                          'product_name':[ "iPhone 13", "Samsung Galaxy S21", "MacBook Pro 16", "AirPods Pro",
                                      "Sony WH-1000XM4", "LG OLED TV", "Samsung QLED TV", "Dell XPS 13",
                                     "Microsoft Surface", "Bose QuietComfort"],
                          
            'rating':[4.8, 4.2, 4.7, 4.4, 4.9, 4.6, 4.7, 4.8, 4.6, 4.9],
                          
            'quantity_in_stock': [10, 0, 5, 3, 2, 15, 12, 3, 4, 7],
                          
             "price": [999.99, 799.99, 2399.99, 249.99, 349.99, 1499.99, 1799.99, 1499.99, 1299.99, 399.99]})
print(df)
# Out:
#    product_id        product_name  rating  quantity_in_stock    price
# 0         101           iPhone 13     4.8                 10   999.99
# 1         102  Samsung Galaxy S21     4.2                  0   799.99
# 2         103      MacBook Pro 16     4.7                  5  2399.99
# 3         104         AirPods Pro     4.4                  3   249.99
# 4         105     Sony WH-1000XM4     4.9                  2   349.99
# 5         106          LG OLED TV     4.6                 15  1499.99
# 6         107     Samsung QLED TV     4.7                 12  1799.99
# 7         108         Dell XPS 13     4.8                  3  1499.99
# 8         109   Microsoft Surface     4.6                  4  1299.99
# 9         110   Bose QuietComfort     4.9                  7   399.99

# %%
print(df.loc[(df['rating']>=4.5) & (df['quantity_in_stock']>0) & (df['price']>299)])
# Out:
#    product_id       product_name  rating  quantity_in_stock    price
# 0         101          iPhone 13     4.8                 10   999.99
# 2         103     MacBook Pro 16     4.7                  5  2399.99
# 4         105    Sony WH-1000XM4     4.9                  2   349.99
# 5         106         LG OLED TV     4.6                 15  1499.99
# 6         107    Samsung QLED TV     4.7                 12  1799.99
# 7         108        Dell XPS 13     4.8                  3  1499.99
# 8         109  Microsoft Surface     4.6                  4  1299.99
# 9         110  Bose QuietComfort     4.9                  7   399.99
